# %% [markdown]
# # Introduction aux Probabilités et Statistiques

# %%
from IPython.display import HTML, Image
import pandas as pd
data = pd.read_csv("../data/data.csv")
data.head(3)
# Out:
#            ID                                           name        category  \
# 0  1000002330                The Songs of Adelaide & Abullah          Poetry
# 1  1000003930  Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 2  1000004038                                 Where is Hank?  Narrative Film
#
#   main_category currency    deadline     goal             launched  pledged  \
# 0    Publishing      GBP  2015-10-09   1000.0  2015-08-11 12:12:28      0.0
# 1  Film & Video      USD  2017-11-01  30000.0  2017-09-02 04:43:57   2421.0
# 2  Film & Video      USD  2013-02-26  45000.0  2013-01-12 00:20:50    220.0
#
#     state  backers country  usd pledged  usd_pledged_real  usd_goal_real
# 0  failed        0      GB          0.0               0.0        1533.95
# 1  failed       15      US        100.0            2421.0       30000.00
# 2  failed        3      US        220.0             220.0       45000.00

# %% [markdown]
# ## –– Sommaire
#
# ### A. Introduction aux probabilités
#
# • Concept de probabilité
# • Théorème de Bayes
#
# ### B. Introduction aux statistiques
#
# • Moyenne, Médiane, Écart-type
# • Fréquences

# %% [markdown]
# ---
#
# ## A. Introduction aux probabilités

# %% [markdown]
# https://openclassrooms.com/fr/courses/4525296-maitrisez-les-bases-des-probabilites

# %%
Image(filename='img/aaaa.png', width="400")

# %% [markdown]
# ## test
# $$\mathbb{P}(A \cup B) = \mathbb{P}(A) + \mathbb{P}(B)$$

# %% [markdown]
# Petite demonstration du phénomène par notre ami <mark>Cédric Villani</mark> lors de sa conférence TED "What's so sexy about math?".

# %%
HTML('<iframe width="400" height="255" src="https://www.youtube.com/embed/Kc0Kthyo0hU?start=250" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="400" height="255" src="https://www.youtube.com/embed/Kc0Kthyo0hU?start=250" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## B. Introduction aux statistiques
#
# https://openclassrooms.com/fr/courses/4525266-decrivez-et-nettoyez-votre-jeu-de-donnees/4729781-decouvrez-les-mesures-de-tendance-centrale

# %%
Image(filename='img/medmoymod.png', width="400")
# Out:
# --------------------------------------------------------------
# FileNotFoundError            Traceback (most recent call last)
# <ipython-input-58-7dc113433763> in <module>()
# ----> 1 Image(filename='img/medmoymod.png', width="400")
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1149         self.unconfined = unconfined
#    1150         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1151                 metadata=metadata)
#    1152
#    1153         if self.width is None and self.metadata.get('width', {}):
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     607             self.metadata = {}
#     608
# --> 609         self.reload()
#     610         self._check_data()
#     611
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/display.py in reload(self)
#    1180         """Reload the raw data from file or URL."""
#    1181         if self.embed:
# -> 1182             super(Image,self).reload()
#    1183             if self.retina:
#    1184                 self._retina_shape()
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/display.py in reload(self)
#     632         """Reload the raw data from file or URL."""
#     633         if self.filename is not None:
# --> 634             with open(self.filename, self._read_flags) as f:
#     635                 self.data = f.read()
#     636         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'img/medmoymod.png'

# %% [markdown]
# ### –– Moyenne

# %%
print(data['usd_goal_real'].mean())
# Out:
# 45454.40146545336

# %% [markdown]
# ### –– Médiane

# %%
print(data['usd_goal_real'].median())
# Out:
# 5500.0

# %% [markdown]
# ### –– Mode

# %%
print(data['usd_goal_real'].mode())
# Out:
# 0    5000.0
# dtype: float64

# %% [markdown]
# ### –– Fréquence
# fréquence d'une modalité = n / N

# %%
effectifs = data["main_category"].value_counts()
modalites = effectifs.index # l'index de effectifs contient les modalités

tab = pd.DataFrame(modalites, columns = ["main_category"]) # création du tableau à partir des modalités
tab["n"] = effectifs.values
tab["f"] = tab["n"] / len(data) # len(data) renvoie la taille de l'échantillon
tab
# Out:
#    main_category      n         f
# 0   Film & Video  63585  0.167921
# 1          Music  51918  0.137109
# 2     Publishing  39874  0.105303
# 3          Games  35231  0.093041
# 4     Technology  32569  0.086011
# 5         Design  30070  0.079411
# 6            Art  28153  0.074349
# 7           Food  24602  0.064971
# 8        Fashion  22816  0.060254
# 9        Theater  10913  0.028820
# 10        Comics  10819  0.028572
# 11   Photography  10779  0.028466
# 12        Crafts   8809  0.023264
# 13    Journalism   4755  0.012557
# 14         Dance   3768  0.009951

# %%
tab = tab.sort_values("main_category") # tri des valeurs de la variable X (croissant)
tab["F"] = tab["f"].cumsum() # cumsum calcule la somme cumulée
tab
